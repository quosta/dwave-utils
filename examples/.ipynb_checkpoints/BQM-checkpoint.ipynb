# %% [markdown]
# # Generate random matrices

# %%
import dwave_utils.utils as dwu 

bqm_dense = dwu.random_dense_bqm(5)
bqm_sparse = dwu.random_sparse_bqm(5, connectivity=0.3)

# %% [markdown]
# ## Display BQMs as heatmaps

# %%
dwu.bqm_info(bqm_dense,verbose=True) #print some info about bqm

dwu.bqm_heatplot(bqm_dense)
# Out:
# num linear weights =  5
# num quadratic weights =  10
# connectivity =  1.0

# %%
dwu.bqm_info(bqm_sparse,verbose=True) #print some info about bqm

dwu.bqm_heatplot(bqm_sparse)
# Out:
# num linear weights =  5
# num quadratic weights =  3
# connectivity =  0.3

# %% [markdown]
# ## Display the distribution of the weights

# %%
dwu.bqm_distplot(bqm_dense)
dwu.bqm_distplot(bqm_sparse)

# %% [markdown]
# ## Save and open the BQM as binary files

# %%
dwu.save_bqm(bqm_dense, './dense_bqm.bqm')

# %%
bqm_dense_new = dwu.open_bqm('./dense_bqm.bqm')

print(bqm_dense_new)
# Out:
# BinaryQuadraticModel({0: 0.5583930842294997, 1: -0.4310814578501627, 2: -0.4121821820018573, 3: 0.43684943488194794, 4: 0.07901734366783175}, {(1, 0): -0.008843489668310944, (2, 0): 0.2197091922505925, (2, 1): 0.2253520785925449, (3, 0): -0.4714763326475926, (3, 1): 0.195287136463971, (3, 2): 0.2567723024744396, (4, 0): -0.5581195449181819, (4, 1): -0.8185428960419671, (4, 2): -0.27468731278815917, (4, 3): 0.38605328196062927}, 0.0, 'BINARY')
